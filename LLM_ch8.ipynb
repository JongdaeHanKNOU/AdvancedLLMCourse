# %%
from openai import OpenAI
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

client = OpenAI()

vector_stores = client.vector_stores.list()

for vector_store in vector_stores.data:
  print(vector_store.name, vector_store.id)

vector_store = vector_stores.data[0]
print(vector_store.name)
# Out:
# knou_rules vs_694b7e15e30c8191aaf497ab5c2d1db2
# knou_rules vs_694b7cfecfbc81919729323a1a96b66e
# knou_rules vs_694b7c919d0c81919b4278af27bb728d
# knou_rules vs_694b7c80a6608191b430ba1da79ca4f5
# knou_rules vs_694b7baa5acc81918a7474b3e552c7c1
# knou_rules vs_694b7b521ef081919a7000ee74015407
# knou_rules vs_694b7b20adb481918c07c405752e183e
# knou_rules vs_694b7a57eb748191b1a558584e9164e9
# knou_rules vs_694b79aef7d081919879ef352d9ba001
# knou_rules vs_694b742456148191be27d5686dc95cb9
# knou_rules vs_694b739384c481918a28ed3918831bf2
# rule_demo vs_694b717ccf54819196930e17c605668f
# knou_rules vs_69474575eb28819182d5eec6983af627
# knou_rules vs_69473fe5c62c81918184d9342e9ef363
# knou_rules vs_6947393a86648191bee652b83f2ae1fa
# knou_rules vs_694738c16c008191b42ca425e84359dd
# rule_demo vs_694724d7a9ec8191af8177ad38c9f86b
# rule_demo vs_6946a221014c81918f8b5e87c776b15e
# knou_rules

# %%
query = "방송통신대에는 어떤 학과가 있나요?"

# 벡터스토어 검색 수행
search_results = client.vector_stores.search(
  vector_store_id=vector_store.id,
  query=query,
  max_num_results=5
)

for result in search_results.data:
  print(result.score, result.content[0].text)
# Out:
# 0.800010567734026 부     칙(2023. 2. 24.  규칙 제1224호)
# 제1조(시행일) 이 학칙은 2023학년도 3월 1일부터 시행한다. 다만 OBHR전공 및 학위명은 2024학년도 3월 1일부터 시행한다.
# 제2조(전공명 및 학위명 변경에 따른 경과조치) ① 이 학칙 시행 당시 HR컨설팅전공 재적생은 OBHR전공 재적생으로, 이 학칙 시행 전에 HR컨설팅전공으로 제적 또는 자퇴한 사람이 재입학하려는 때에는 OBHR 전공에서 제적 또는 자퇴한 것으로 본다.
#   ② 이 학칙 시행 당시 테크노경영전공 재적생은 DS전공 재적생으로, 이 학칙 시행 전에 테크노경영전공으로 제적 또는 자퇴한 사람이 재입학하려는 때에는 DS전공에서 제적 또는 자퇴한 것으로 본다.
#
#  부     칙(2023. 2. 28.  규칙 제1225호)
# 이 학칙은 공포한 날부터 시행한다.
#
# 부     칙(2023. 7. 19.  규칙 제1233호)
# 제1조(시행일) 이 학칙은 2024학년도 3월 1일부터 시행한다.
# 제2조(대학원 학과명 및 학위명 변경에 따른 경과조치) ① 이 학칙 시행 당시 이러닝학과 재적생은 이 학칙에 따른 에듀테크학과 재적생으로 본다.
#   ② 이 학칙 시행 전에 이러닝학과에서 제적 또는 자퇴한 사람이 재입학하려는 때에는 이 학칙에 따른 에듀테크학과에서 제적 또는 자퇴한 것으로 본다.
# 제3조(다른 규정과의 관계) 이 학칙 시행 당시 본교의 다른 규정에서 이 학칙으로 변경되는 종전의 학과명, 전공명 또는 학위명을 인용한 경우에는 이 학칙의 해당 학과명, 전공명 또는 학위명을 인용한 것으로 본다.
#
# 부     칙(2023. 7. 26.  규칙 제1234호)
# 이 학칙은 공포한 날부터 시행한다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [별표 1] 단과대학별 설치학과(부)·전공 및 입(편)학정원(제40조제1항 관련)
# (개정 2022.11.9., 2023.7.19.)
#
# 	단과대학명
# 	학과(부)명
# 	입 학 (편 입 학) 정 원
#
#
#
# 	1학년
# 	3학년
# 	합계
#
# 	인문
# 과학
# 대학
#
# 	국 어 국 문 학 과
# 영 어 영 문 학 과
# 중 어 중 문 학 과
# 프랑스언어문화학과
# 일 본 학 과
# 	2,510명
# 4,440명
# 3,360명
#   750명
# 2,710명
#
# 	2,510명
# 4,440명
# 3,360명
#   750명
# 2,710명
#
# 	사회
# 과학
# 대학
# 	법 학 과
# 행 정 학 과
# 경 제 학 과
# 경 영 학 과
# 무 역 학 과
# 미 디 어 영 상 학 과
# 관 광 학 과
# 사회복지학과
# 	3,350명
# 1,720명
# 1,200명
# 4,370명
# 1,070명
# 1,820명
# 1,760명
# 1,200명
# 0.7407007210276771 부     칙(2022. 10. 28.  규칙 제1212호)
# 제1조(시행일) 이 학칙은 2023학년도부터 시행한다.
#
#  부     칙(2022. 11. 9.  규칙 제1213호)
# 제1조(시행일) 이 학칙은 2023년 3월 1일부터 시행한다.
# 제2조(학부 전공명칭 변경에 따른 경과조치) ① 이 학칙 시행 당시 생활과학부 가정복지학전공 재적생은 생활과학부 가정복지상담학전공 재적생으로 본다.
#   ② 이 학칙 시행 전에 생활과학부 가정복지학전공에서 제적 또는 자퇴한 사람이 재입학하려는 때에는 생활과학부 가정복지상담학전공에서 제적 또는 자퇴한 것으로 본다.
# 제3조(대학원 학과명칭 변경에 따른 경과조치) ① 이 학칙 시행 당시 바이오정보·통계학과 재적생은 통계·데이터과학과 재적생으로 본다.
#   ② 이 학칙 시행 전에 바이오정보·통계학과에서 제적 또는 자퇴한 사람이 재입학하려는 때에는 통계·데이터과학과에서 제적 또는 자퇴한 것으로 본다.
# 제4조(다른 규정과의 관계) 이 학칙 시행 당시 본교의 다른 규정에서 이 학칙으로 변경되는 종전의 학과명, 전공명 또는 학위명을 인용한 경우에는 이 학칙의 해당 학과명, 전공명 또는 학위명을 인용한 것으로 본다.
#
#  부     칙(2022. 12. 20.  규칙 제1218호)
# 제1조(시행일) 이 학칙은 공포한 날부터 시행한다.
# 제2조(교직원에 대한 경과조치) 원격교육연구소 소속 교직원은 미래원격교육연구원 소속 교직원으로 본다.
# 제3조(다른 규정과의 관계) 이 학칙 시행 당시 다른 규정에서 원격교육연구소를 인용한 경우에는 이 학칙에 의하여 미래원격교육연구원을 인용한 것으로 본다.
#
#  부     칙(2023. 2. 24.  규칙 제1224호)
# 제1조(시행일) 이 학칙은 2023학년도 3월 1일부터 시행한다. 다만 OBHR전공 및 학위명은 2024학년도 3월 1일부터 시행한다.
# 제2조(전공명 및 학위명 변경에 따른 경과조치) ① 이 학칙 시행 당시 HR컨설팅전공 재적생은 OBHR전공 재적생으로, 이 학칙 시행 전에 HR컨설팅전공으로 제적 또는 자퇴한 사람이 재입학하려는 때에는 OBHR 전공에서 제적 또는 자퇴한 것으로 본다.
#   ② 이 학칙 시행 당시 테크노경영전공 재적생은 DS전공 재적생으로, 이 학칙 시행 전에 테크노경영전공으로 제적 또는 자퇴한 사람이 재입학하려는 때에는 DS전공에서 제적 또는 자퇴한 것으로 본다.
#
#  부     칙(2023. 2. 28.  규칙 제1225호)
# 이 학칙은 공포한 날부터 시행한다.
# 0.7221819830556767 [별표 1] 단과대학별 설치학과(부)·전공 및 입(편)학정원(제40조제1항 관련)
# (개정 2022.11.9., 2023.7.19.)
#
# 	단과대학명
# 	학과(부)명
# 	입 학 (편 입 학) 정 원
#
#
#
# 	1학년
# 	3학년
# 	합계
#
# 	인문
# 과학
# 대학
#
# 	국 어 국 문 학 과
# 영 어 영 문 학 과
# 중 어 중 문 학 과
# 프랑스언어문화학과
# 일 본 학 과
# 	2,510명
# 4,440명
# 3,360명
#   750명
# 2,710명
#
# 	2,510명
# 4,440명
# 3,360명
#   750명
# 2,710명
#
# 	사회
# 과학
# 대학
# 	법 학 과
# 행 정 학 과
# 경 제 학 과
# 경 영 학 과
# 무 역 학 과
# 미 디 어 영 상 학 과
# 관 광 학 과
# 사회복지학과
# 	3,350명
# 1,720명
# 1,200명
# 4,370명
# 1,070명
# 1,820명
# 1,760명
# 1,200명
#
#
#
#
#
#
#
# 3,000명
# 	3,350명
# 1,720명
# 1,200명
# 4,370명
# 1,070명
# 1,820명
# 1,760명
# 4,200명
#
# 	자연
# 과학
# 대학
# 	농 학 과
# 생 활 과 학 부
# (가 정 복 지 상 담 학 전 공)
#
# (식 품 영 양 학 전 공)
#
#
# (의 류 패 션 학 전 공)
#
# 컴 퓨 터 과 학 과
# 통 계 · 데 이 터 과 학 과
# 보 건 환 경 학 과
# 간 호 학 과
# 	1,000명
# 4,500명
# (-)
#
# (-)
#
#
# (-)
#
# 3,040명
# 1,000명
# 1,580명
# -
# 	1,500명
# 1,000명
# (전공분리
# 2,300명)
# 1,000명
# (전공분리
# 1,000명 별도)
# (전공분리
# 1,200명)
#
# 250명
#
# 2,500명
# 	2,500명
# 5,500명
# (2,300명)
#
# (2,000명)
#
#
# (1,200명)
#
# 3,040명
# 1,250명
# 1,580명
# 2,500명
#
# 	교육
# 과학
# 대학
# 	교 육 학 과
# 청 소 년 교 육 과
# 유 아 교 육 과
# 문 화 교 양 학 과
# 생 활 체 육 지 도 과
# 	2,800명
# 2,910명
# 1,890명
# 1,760명
# 1,500명
#
#
# 2,000명
#
# 560명
# 	2,800명
# 2,910명
# 3,890명
# 1,760명
# 2,060명
#
#
# 	계
# 	52,240명
# 	10,810명
# 	63,050명
#
#
#
#
#
#
#
#
#
# [별표 2] 대학원 설치학과 및 입학정원(제6조제4항 관련)
# (개정 2022.11.9., 2023.7.19.)
#
# 	대학원명
# 	학과 및 전공명
# 	입학정원
#
#
#
#
#
#
#
#
# 대학원
# 	문예창작콘텐츠학과
# 실용영어학과
# 실용중국어학과
# 아프리카‧불어권언어문화학과
# 일본언어문화학과
# 법학과
# 행정학과
# 영상문화콘텐츠학과
# 사회복지학과
# 농업생명과학과
# 생활과학과
# 정보과학과
# 에듀테크학과
# 통계·데이터과학과
# 환경보건시스템학과
# 간호학과
# 평생교육학과
# 청소년교육학과
# 유아교육학과
# 	830

# %%
files = client.files.list()
for f in files.data:
  print(f.id, f.filename)

file = files.data[0]
print(file)
# Out:
# file-Mr8Y39arcqSsL7zeERuyLH 한국방송통신대학교 학칙.pdf
# file-KDqENryyDaMvVWHqKdJJg5 한국방송통신대학교 학칙.pdf
# file-Hk2RF99djdfsqPzm9my8JQ 한국방송통신대학교 학칙.pdf
# file-KtUGmwD8RYJEiyYDtQNdPW 한국방송통신대학교 학칙.pdf
# file-EH9fGmsagohL1Lg58eZqdH 한국방송통신대학교 학칙.pdf
# file-7SsNYDWPA1x7R28kE6o727 한국방송통신대학교 학칙.pdf
# file-TZo3hXpBAxycQDfxGf32Cw 한국방송통신대학교 학칙.docx
# file-2ACgrjmLxqPS82rmNanVDT 한국방송통신대학교 학칙.pdf
# file-TSswV857iuNQ8okWA0yQyl9x step_metrics.csv
# file-a1asGVA48iFmLQl51yRV4V6x FOR_FINE_20240315_1638.jsonl
# file-bMYBNpyEpowpHAWipGIoQJ0Z FOR_FINE_20240315_1630.jsonl
# file-667aIGqROkB1ic56ZMYRx6xn FOR_FINE_20240315_1508.jsonl
# FileObject(id='file-Mr8Y39arcqSsL7zeERuyLH', bytes=941634, created_at=1766554950, filename='한국방송통신대학교 학칙.pdf', object='file', purpose='assistants', status='processed', expires_at=None, status_details=None)

# %%
# 파일 업로드
file = client.files.create(
    file=open("한국방송통신대학교 학칙.docx", "rb"),
    purpose="assistants"
)

# %%
# Vector Store 재생성
client.vector_stores.delete(vector_store.id)
vector_store = client.vector_stores.create(
  name="knou_rules",
  metadata={
    "description": "한국방송통신대학교 학칙"
   },
  chunking_strategy={
    'type': 'static',
    'static': {
      'max_chunk_size_tokens': 1600,
      'chunk_overlap_tokens': 800
    }
  }, # 또는 auto
  file_ids = [file.id] #웹 또는 client.files.list() 이용해 확인
)

print(vector_store)
# Out:
# VectorStore(id='vs_694b8884eee08191a2103b885d7bc4a2', created_at=1766557829, file_counts=FileCounts(cancelled=0, completed=0, failed=0, in_progress=1, total=1), last_active_at=1766557829, metadata={'description': '한국방송통신대학교 학칙'}, name='knou_rules', object='vector_store', status='in_progress', usage_bytes=0, expires_after=None, expires_at=None, description=None)

# %%
import time

def wait_for_vectorization(vector_store_id: str, file_id: str, poll_interval: int = 2):
    while True:
        vs_file = client.vector_stores.files.retrieve(
            vector_store_id=vector_store_id,
            file_id=file.id,
        )
        print("현재 상태:", vs_file.status)

        if vs_file.status in ("completed", "failed", "cancelled"):
            return vs_file

        time.sleep(poll_interval)

final_vs_file = wait_for_vectorization(vector_store.id, file.id)
print("최종 상태:", final_vs_file.status)
# Out:
# 현재 상태: in_progress
# 현재 상태: in_progress
# 현재 상태: in_progress
# 현재 상태: in_progress
# 현재 상태: in_progress
# 현재 상태: in_progress
# 현재 상태: completed
# 최종 상태: completed

# %%
# 파일 업로드
file = client.files.create(
    file=open("한국방송통신대학교 학칙.docx", "rb"),
    purpose="assistants"
)

# Vector Store에 파일 추가
client.vector_stores.files.create(
    vector_store_id=vector_store.id,
    file_id=file.id
)
# Out:
# VectorStoreFile(id='file-LNPzX8VbcNDAfmBuuMzL9S', created_at=1766277335, last_error=None, object='vector_store.file', status='in_progress', usage_bytes=0, vector_store_id='vs_6947395b3ec081918f11d82142165bad', attributes={}, chunking_strategy=StaticFileChunkingStrategyObject(static=StaticFileChunkingStrategy(chunk_overlap_tokens=400, max_chunk_size_tokens=800), type='static'))

# %%
question = "방송통신대에는 어떤 본교 부속시설이 있나요?"

response = client.responses.create(
    model="gpt-4.1-mini",
    input=question,
    instructions="당신은 학사정보 상담사입니다. 제공된 학칙 문서를 기반으로 정확한 답변을 제공해주세요. 답변 마지막에는 참조한 문서에서 해당하는 부분의 내용을 <출처 : > 안에 표시해주세요. 예 : <출처 : 제 9 조>",
    temperature=0.2,
    tools=[
        {
            "type": "file_search",
            "vector_store_ids": [vector_store.id],
            "max_num_results": 5
        }
    ],
    include=["file_search_call.results"]
)

print(response.output_text)
print(response.output[0].results[0].text)
# Out:
# 방송통신대학교 본교의 부속시설은 다음과 같습니다.
#
# 1. 평생교육원
# 2. 종합교육연수원
# 3. 교양교육원
# 4. 역사기록관
# 5. 인재개발원
# 6. 국제협력단
# 7. 산학협력단
# 8. 인권센터(신설)
#
# 또한 본교에는 다음과 같은 연구시설도 두고 있습니다.
# - 미래원격교육연구원
# - 통합인문학연구소
#
# 이 외에도 지역대학과 디지털미디어센터, 중앙도서관 등의 부속시설이 있습니다.
#
# 이 부속시설들은 본교의 교육 및 연구, 학생 지원 등을 위해 운영되고 있으며, 각 부속시설의 장은 관련 단과대학이나 학과(부)의 장이 겸직하거나 총장이 별도로 임명할 수 있습니다.
#
# 자세한 내용은 한국방송통신대학교 학칙 제4절 부속 시설 등(제22조~제25조)에 명시되어 있습니다.
# 이에 관한 사항은 총장이 따로 정한다.(신설 2023.2.28.)
#   ③ 전임교수의 교수시간에 관해서는 총장이 따로 정한다.(개정 2023.2.28.)
# 제12조(강사) ① 총장은 고등교육법 제14조의2 및 같은 법 시행령 제4조의11에 따라 강사를 임용할 수 있다.(개정 2023.2.28.)
#   ② 강사의 임용․재임용 절차 및 그밖의 필요한 사항은 총장이 따로 정한다.
# 제13조(겸임교원 등) ① 총장은 고등교육법 제17조 및 같은 법 시행령 제7조에 따라 겸임교원․명예교수․초빙교원 등을 각각 임용하거나 위촉할 수 있다.
#   ② 제1항에 따른 겸임교원 등의 임용 또는 위촉에 관한 사항은 총장이 따로 정한다.
# 제14조(학생의 소속) 본교의 학생은 본교의 1개 학과(부)에 한정하여 학적을 가진다.
#
# 제3절 행정 조직
# 제15조(처․국 등) ① 본교에 교무처․학생처․기획처 · 사무국 및 교육정보화본부를 둔다.
#   ② 대학 및 대학원의 운영을 지원하기 위하여 행정실을 두되, 2개 이상의 대학 및 대학원 운영을 지원하기 위하여 행정실을 통합하여 운영할 수 있다.
#   ③ 제1항, 제2항의 그 하부조직과 부속시설 등의 사무분장에 관한 사항은 한국방송통신대학교 직제 및 사무분장에 관한 규정으로 정한다.
# 제16조(교무처) ① 교무처에 처장을 두며, 교원 및 조교의 인사, 학생정원 관리, 교수업적평가 기획, 각종 시험 등교무·학사 전반에 관한 사항을 담당한다.
#   ② 교무처장의 직무를 보좌하기 위하여 교무부처장을 둔다.
# 제17조(학생처) ① 학생처에 처장을 두며 학생처장은 학생활동 지도ㆍ지원, 지역대학 운영, 입학ㆍ학생선발ㆍ학사ㆍ진로 상담 등에 관한 사항을 담당한다.
#   ② 학생처장의 직무를 보좌하기 위하여 학생부처장을 둔다.
# 제18조(기획처) ① 기획처에 처장을 두며 기획처장은 대학운영의 기획ㆍ조정, 대학 평가, 대외협력 사업 및 홍보등에 관한 사항을 담당한다.
#   ② 기획처장의 직무를 보좌하기 위하여 기획부처장을 둔다.
# 제19조(사무국) 사무국에 국장을 두며, 국장의 분장사무는「한국방송통신대학교 설립 및 운영에 관한 법률 시행령 (이하“시행령”이라 한다)」제7조에 따른다.
# 제20조(교육정보화본부) 교육정보화본부에 본부장을 두며, 정보화본부장은 대학정보화 종합 기획ㆍ조정, 정보시스템의 개발ㆍ운영, 전산망 구축 및 정보보안에 관한 사항을 담당한다.
# 제21조(정보화책임관) 대학의 정보화를 체계적으로 추진하기 위하여 정보화책임관을 두며, 부총장이 정보화책임관이 된다.
# 제4절 부속 시설 등
# 제22조(부속시설 등) ① 시행령 제6조에 따라 지역대학, 디지털미디어센터를 둔다.
#   ② ｢대학도서관진흥법｣ 제6조 제1항에 따라 본교에 교육기본시설로 중앙도서관을 둔다.
#   ③ 본교에 다음 각 호의 부속시설을 둔다.
#    1. 평생교육원
#    2. 종합교육연수원
#    3. 교양교육원
#    4. 역사기록관
#    5. 인재개발원
#    6. 국제협력단
#    7. 산학협력단
#    8. 인권센터(신설)
#   ④ 본교에 다음 각 호의 연구시설을 둔다.
#    1.

# %%
from vespa.application import Vespa

app = Vespa(url="http://localhost:8080")
response = app.feed_data_point(
    schema="doc",
    data_id="id:ns:doc::1",
    fields={
        "id": 1,
        "title": "1조",
        "description": "(목적) 이 학칙은 한국방송통신대학교의 교육목표를...",
        "vector": [0.1, 0.2, ..., 0.8]  # 768차원
    }
)
